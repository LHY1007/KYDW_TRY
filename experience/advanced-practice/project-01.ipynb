# %% [markdown]
# # 进阶实践项目 00：基础编程与人工智能：稳健性与概率评价
#
# 在手写数字分类之后，继续检查模型面对噪声、类别不平衡和概率解释时是否可靠。
#
# Kaggle 中先复制到自己的账户，再按任务顺序完成。题目只保留关键填写位置，数据读取、绘图和保存框架已经给出。
#
# ## 任务
# 1. 完成分层划分与标准化
# 2. 训练逻辑回归和随机森林
# 3. 计算宏平均 F1 与混淆矩阵
# 4. 绘制可靠性曲线
# 5. 比较加噪前后的性能

# %%
# 先阅读教学项目，再逐项补全。参考版与本题目的任务顺序一致。
# TODO 1：完成数据划分或样本单位检查。
# TODO 2：完成基线与主要方法。
# TODO 3：计算与任务对应的评价指标。
# TODO 4：绘制结果并检查错误。
# TODO 5：保存结果并用一段话说明结论边界。
raise NotImplementedError('请完成以上五项任务后运行；可参考教学页中的输入、方法和评价说明。')
